# %% [markdown]
# # Main Notebook - Hackathon Project 2/2022

# %% [markdown]
# ## Part I. Data Inspection, Pre-Processing and Cleaning

# %%
import fnmatch
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

import seaborn as sns
sns.set_theme(style='darkgrid')

import sklearn.metrics
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    RandomizedSearchCV,
    cross_val_score
)
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
    BaggingClassifier,
)
from xgboost import XGBClassifier

import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

import warnings

warnings.filterwarnings("ignore")

# %%
#import training and test data into pandas dataframe and make copies
raw_train_data = pd.read_csv('Train_set.csv')
raw_test_data  = pd.read_csv('Test_set.csv')

train_data     = raw_train_data.copy(deep=True)
test_data     = raw_test_data.copy(deep=True)

# %%
train_data.head()
# Out:
#          ID  loan_amnt loan_term  interest_rate loan_grade loan_subgrade  \
# 0  72199369       9000   3 years           9.17          B            B2
# 1  14257956      18000   3 years          13.65          C            C1
# 2  66216451      16000   3 years           7.26          A            A4
# 3  46974169      25000   3 years          13.99          C            C4
# 4  46725961      17000   3 years           6.39          A            A2
#
#   job_experience home_ownership  annual_income income_verification_status  \
# 0       <5 Years            OWN        85000.0               Not Verified
# 1       <5 Years            OWN        64000.0                   Verified
# 2       <5 Years       MORTGAGE       150000.0            Source Verified
# 3            NaN       MORTGAGE        59800.0                   Verified
# 4      10+ years       MORTGAGE        72000.0            Source Verified
#
#    ... delinq_2yrs public_records  revolving_balance  total_acc  \
# ...

# %%
train_data.describe(include='all')
# Out:
#                   ID     loan_amnt loan_term  interest_rate loan_grade  \
# count   9.317400e+04  93174.000000     93174   93174.000000      93174
# unique           NaN           NaN         2            NaN          7
# top              NaN           NaN   3 years            NaN          B
# freq             NaN           NaN     65211            NaN      26865
# mean    3.505021e+07  14733.861378       NaN      13.233433        NaN
# std     2.414926e+07   8428.184858       NaN       4.368728        NaN
# min     7.073500e+04    500.000000       NaN       5.320000        NaN
# 25%     1.085983e+07   8000.000000       NaN       9.990000        NaN
# 50%     3.710751e+07  13000.000000       NaN      12.990000        NaN
# 75%     5.859895e+07  20000.000000       NaN      16.200000        NaN
# max     7.351975e+07  35000.000000       NaN      28.990000        NaN
#
#        loan_subgrade job_experience home_ownership  annual_income  \
# ...

# %%
#check for duplicate values
train_data.duplicated().sum()
# Out:
# 0

# %%
test_data.duplicated().sum()
# Out:
# 0

# %%
#check for missing values
train_data.isnull().sum()
# Out:
# ID                               0
# loan_amnt                        0
# loan_term                        0
# interest_rate                    0
# loan_grade                       0
# loan_subgrade                    0
# job_experience                4702
# home_ownership                   0
# annual_income                    1
# income_verification_status       0
# loan_purpose                     0
# state_code                       0
# debt_to_income                   0
# delinq_2yrs                      2
# public_records                   2
# revolving_balance                0
# total_acc                        2
# interest_receive                 0
# application_type                 0
# last_week_pay                 1924
# total_current_balance         7386
# total_revolving_limit         7386
# default                          0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# ID                               0
# loan_amnt                        0
# loan_term                        0
# interest_rate                    0
# loan_grade                       0
# loan_subgrade                    0
# job_experience                2089
# home_ownership                   0
# annual_income                    0
# income_verification_status       0
# loan_purpose                     0
# state_code                       0
# debt_to_income                   0
# delinq_2yrs                      1
# public_records                   1
# revolving_balance                0
# total_acc                        1
# interest_receive                 0
# application_type                 0
# last_week_pay                  806
# total_current_balance         3230
# total_revolving_limit         3230
# dtype: int64

# %%
#unique ID is for record keeping and unique to each entry - check to make sure no IDs
#are included in test set and training set by mistake
print(all((np.where(train_data["ID"].isin(test_data["ID"])), True, False)))
# Out:
# False

# %%
#no user IDs are inadvertently included in both data sets. We can safely drop ID as an identifier because it
#is completely unique
train_data.drop("ID", axis=1, inplace=True)
test_data.drop("ID", axis=1, inplace=True)

train_data.head()
# Out:
#    loan_amnt loan_term  interest_rate loan_grade loan_subgrade job_experience  \
# 0       9000   3 years           9.17          B            B2       <5 Years
# 1      18000   3 years          13.65          C            C1       <5 Years
# 2      16000   3 years           7.26          A            A4       <5 Years
# 3      25000   3 years          13.99          C            C4            NaN
# 4      17000   3 years           6.39          A            A2      10+ years
#
#   home_ownership  annual_income income_verification_status  \
# 0            OWN        85000.0               Not Verified
# 1            OWN        64000.0                   Verified
# 2       MORTGAGE       150000.0            Source Verified
# 3       MORTGAGE        59800.0                   Verified
# 4       MORTGAGE        72000.0            Source Verified
#
#          loan_purpose  ... delinq_2yrs  public_records  revolving_balance  \
# ...

# %%
test_data.head()
# Out:
#    loan_amnt loan_term  interest_rate loan_grade loan_subgrade job_experience  \
# 0      12000   3 years          15.31          C            C2       <5 Years
# 1      12000   3 years           7.26          A            A4      10+ years
# 2      15000   3 years          14.33          C            C1     6-10 years
# 3      12000   3 years           9.99          B            B3     6-10 years
# 4      20150   3 years          11.53          B            B5       <5 Years
#
#   home_ownership  annual_income income_verification_status  \
# 0       MORTGAGE        73400.0               Not Verified
# 1       MORTGAGE       105000.0               Not Verified
# 2       MORTGAGE        50000.0                   Verified
# 3           RENT        37000.0            Source Verified
# 4           RENT        75000.0            Source Verified
#
#          loan_purpose  ... debt_to_income  delinq_2yrs  public_records  \
# ...

# %%
#let's check each of the columns to learn more about the nature of the missing values and the data types
train_data["loan_amnt"].nunique()
# Out:
# 1310

# %%
#checking to make sure there are no zero or negative loan amounts
print(any(np.where(train_data["loan_amnt"] <= 0, True, False)))
# Out:
# False

# %%
print(any(np.where(test_data["loan_amnt"] <= 0, True, False)))
# Out:
# False

# %%
#repeat for interest rate
print(any(np.where(train_data["interest_rate"] <= 0, True, False)))
# Out:
# False

# %%
print(any(np.where(test_data["interest_rate"] <= 0, True, False)))
# Out:
# False

# %%
#repeat for annual income
print(any(np.where(train_data["annual_income"] <= 0, True, False)))
# Out:
# False

# %%
print(any(np.where(test_data["annual_income"] <= 0, True, False)))
# Out:
# False

# %%
#checking debt-to-income ratio
print(any(np.where(train_data["debt_to_income"] < 0, True, False)))
# Out:
# False

# %%
print(any(np.where(test_data["debt_to_income"] < 0, True, False)))
# Out:
# False

# %%
#checking delinquency numbers for 0 to positive only
print(any(np.where(train_data["delinq_2yrs"] < 0, True, False)))
# Out:
# False

# %%
print(any(np.where(test_data["delinq_2yrs"] < 0, True, False)))
# Out:
# False

# %%
#checking public records
print(any(np.where(train_data["public_records"] < 0, True, False)))
# Out:
# False

# %%
print(any(np.where(train_data["public_records"] < 0, True, False)))
# Out:
# False

# %%
#everything looks good there, checking values to determine what to do with nulls
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93174 entries, 0 to 93173
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   loan_amnt                   93174 non-null  int64
#  1   loan_term                   93174 non-null  object
#  2   interest_rate               93174 non-null  float64
#  3   loan_grade                  93174 non-null  object
#  4   loan_subgrade               93174 non-null  object
#  5   job_experience              88472 non-null  object
#  6   home_ownership              93174 non-null  object
#  7   annual_income               93173 non-null  float64
#  8   income_verification_status  93174 non-null  object
#  9   loan_purpose                93174 non-null  object
#  10  state_code                  93174 non-null  object
#  11  debt_to_income              93174 non-null  float64
#  12  delinq_2yrs                 93172 non-null  float64
# ...

# %%
train_data.isnull().sum()
# Out:
# loan_amnt                        0
# loan_term                        0
# interest_rate                    0
# loan_grade                       0
# loan_subgrade                    0
# job_experience                4702
# home_ownership                   0
# annual_income                    1
# income_verification_status       0
# loan_purpose                     0
# state_code                       0
# debt_to_income                   0
# delinq_2yrs                      2
# public_records                   2
# revolving_balance                0
# total_acc                        2
# interest_receive                 0
# application_type                 0
# last_week_pay                 1924
# total_current_balance         7386
# total_revolving_limit         7386
# default                          0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# loan_amnt                        0
# loan_term                        0
# interest_rate                    0
# loan_grade                       0
# loan_subgrade                    0
# job_experience                2089
# home_ownership                   0
# annual_income                    0
# income_verification_status       0
# loan_purpose                     0
# state_code                       0
# debt_to_income                   0
# delinq_2yrs                      1
# public_records                   1
# revolving_balance                0
# total_acc                        1
# interest_receive                 0
# application_type                 0
# last_week_pay                  806
# total_current_balance         3230
# total_revolving_limit         3230
# dtype: int64

# %%
#null values in job exp, annual income, total_acc, last_week_pay, total_current_balance, total_revolving_limit...
#let's take a look at these value counts for some more insight
train_data["job_experience"].value_counts()
# Out:
# <5 Years      40610
# 10+ years     30362
# 6-10 years    17500
# Name: job_experience, dtype: int64

# %%
train_data["loan_term"].value_counts()
# Out:
# 3 years    65211
# 5 years    27963
# Name: loan_term, dtype: int64

# %%
test_data["loan_term"].value_counts()
# Out:
# 3 years    28110
# 5 years    11823
# Name: loan_term, dtype: int64

# %%
train_data["loan_term"].value_counts()
# Out:
# 3 years    65211
# 5 years    27963
# Name: loan_term, dtype: int64

# %%
train_data["loan_grade"].value_counts()
# Out:
# B    26865
# C    25787
# A    15534
# D    14715
# E     7378
# F     2344
# G      551
# Name: loan_grade, dtype: int64

# %%
test_data["loan_grade"].value_counts()
# Out:
# B    11551
# C    10948
# A     6764
# D     6237
# E     3158
# F     1030
# G      245
# Name: loan_grade, dtype: int64

# %%
train_data["loan_subgrade"].value_counts()
# Out:
# B3    5879
# B4    5879
# C2    5479
# C1    5443
# C3    5270
# C4    5182
# B2    5169
# B5    5095
# B1    4843
# A5    4723
# C5    4413
# D1    3716
# A4    3631
# D2    3239
# D3    2759
# D4    2717
# A3    2450
# A1    2377
# A2    2353
# D5    2284
# E1    1924
# E2    1736
# E3    1513
# E4    1228
# E5     977
# F1     745
# F2     545
# F3     465
# F4     355
# F5     234
# G1     174
# G2     146
# G3     105
# G5      66
# G4      60
# Name: loan_subgrade, dtype: int64

# %%
test_data["loan_subgrade"].value_counts()
# Out:
# B3    2547
# B4    2519
# C1    2436
# C2    2371
# B5    2247
# C3    2220
# B2    2206
# C4    2084
# A5    2069
# B1    2032
# C5    1837
# D1    1576
# A4    1559
# D2    1373
# D3    1175
# D4    1141
# A3    1074
# A1    1067
# A2     995
# D5     972
# E1     803
# E2     755
# E3     652
# E4     519
# E5     429
# F1     312
# F2     254
# F3     195
# F4     147
# F5     122
# G2      72
# G1      71
# G3      46
# G5      31
# G4      25
# Name: loan_subgrade, dtype: int64

# %%
#double-check that none of the sub-grades are mis-labeled by summing
print(train_data["loan_subgrade"].str.contains("A").sum() == train_data["loan_grade"].str.contains("A").sum())
print(train_data["loan_subgrade"].str.contains("B").sum() == train_data["loan_grade"].str.contains("B").sum())
print(train_data["loan_subgrade"].str.contains("C").sum() == train_data["loan_grade"].str.contains("C").sum())
print(train_data["loan_subgrade"].str.contains("D").sum() == train_data["loan_grade"].str.contains("D").sum())
print(train_data["loan_subgrade"].str.contains("E").sum() == train_data["loan_grade"].str.contains("E").sum())
print(train_data["loan_subgrade"].str.contains("F").sum() == train_data["loan_grade"].str.contains("F").sum())
print(train_data["loan_subgrade"].str.contains("G").sum() == train_data["loan_grade"].str.contains("G").sum())
# Out:
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Part II. Exploratory Data Analysis

# %%
#random code bits I want to use to try and make pretty plots from an old project
#let's make some better-looking histograms
'''
#get breakdown of customer demographics by preferred language
graph = sns.countplot(abtest["language_preferred"], palette='autumn')
plt.xlabel("Preferred Language", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Count", fontsize=18)
plt.yticks(fontsize=14)

for p in graph.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1,height ,ha="center", fontsize=14)
    
    
 #Let's plot a normalized histogram, including the standard deviation and a kde plot.
sns.distplot(abtest['time_spent_on_the_page'])

plt.axvline(abtest.time_spent_on_the_page.mean(), color='navy', linestyle="--", label=r"$\mu_{\bar{x}}$")
plt.axvline(abtest.time_spent_on_the_page.median(), color='cyan', linestyle=":", label="Median")
plt.axvline(abtest.time_spent_on_the_page.mean() + abtest.time_spent_on_the_page.std(),
            color='red', linestyle=":", label=r"$\mu_{\bar{x}} \pm \sigma_{\bar{x}}$")
plt.axvline(abtest.time_spent_on_the_page.mean() - abtest.time_spent_on_the_page.std(),
            color='red', linestyle=":")

plt.legend(fontsize=18)
plt.xlabel("Time Spent on the page (Minutes)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Relative Frequency", fontsize=18)
plt.yticks(fontsize=14)


print("Mean: %.3f" % abtest.time_spent_on_the_page.mean())
print("Median: %.3f" % abtest.time_spent_on_the_page.median())
print("Sigma: %.3f" % abtest.time_spent_on_the_page.std())    
    
'''

print('hi how are you?')
# Out:
# hi how are you?

# %%
#plot to make a histogram on top of a boxplot from the course I was in. Going to use this for EDA and to
#try to get more insights about the data I'll be building a model from.
#I should mention this is only going to be used with numerical (continuous data)

def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots - this really helps me get a conceptual idea of what my categorial variables look like.


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
#pretty hist is a little over-confident but I'm used to seeing that language in convenience plotting functions :D
#(especially since I'm basically working off of the seaborn function)
def pretty_hist(data, feature, xlimit=None, ylimit=None):

    #Let's plot a normalized histogram, including the standard deviation and a kde plot.
    sns.distplot(data[feature])

    plt.axvline(data[feature].mean(), color='navy', linestyle="--", label=r"$\mu_{\bar{x}}$")
    plt.axvline(data[feature].median(), color='cyan', linestyle=":", label="Median")
    plt.axvline(data[feature].mean() + data[feature].std(),
            color='red', linestyle=":", label=r"$\mu_{\bar{x}} \pm \sigma_{\bar{x}}$")
    plt.axvline(data[feature].mean() - data[feature].std(),
            color='red', linestyle=":")

    plt.legend(fontsize=18)
    
    #plt.xlabel("Time Spent on the page (Minutes)", fontsize=18)
    plt.xticks(fontsize=14)
    if xlimit is not None:
        plt.xlim(xlimit)
    
    #plt.ylabel("Relative Frequency", fontsize=18)
    plt.yticks(fontsize=14)
    if ylimit is not None:
        plt.ylim(ylimit)

# %%
#re-print my feature names here so I don't have to keep scrolling back and forth as much
train_data.columns
# Out:
# Index(['loan_amnt', 'loan_term', 'interest_rate', 'loan_grade',
#        'loan_subgrade', 'job_experience', 'home_ownership', 'annual_income',
#        'income_verification_status', 'loan_purpose', 'state_code',
#        'debt_to_income', 'delinq_2yrs', 'public_records', 'revolving_balance',
#        'total_acc', 'interest_receive', 'application_type', 'last_week_pay',
#        'total_current_balance', 'total_revolving_limit', 'default'],
#       dtype='object')

# %% [markdown]
# ### EDA on Numerical Data

# %%
histogram_boxplot(train_data, 'loan_amnt')

# %%
histogram_boxplot(train_data, 'interest_rate')

# %%
#this one's got a ton of outliers, there's some millionaires in here. Might be best to do some outlier clipping on this feature.
#that said, we're going to be building a classification model for predicting whether an applicant for a loan is going
#to default, so we might not need to treat the outliers here outside of the logistic regression model I want to try.
histogram_boxplot(train_data, 'annual_income')

# %%
#let's try calling that new function
#i'll need to set limits on this to get it to look better
#probably would look better logarithmically too, but...the goal here isn't beautiful presentation-level plots yet,
#we're just trying to explore the data for now
pretty_hist(train_data, 'annual_income', xlimit=[0, 0.5e6])

# %% [markdown]
# gross!!! Coming back to this later lol

# %%
#I need to remember to copy those column names instead of trying to memorize them XD
histogram_boxplot(train_data, 'debt_to_income')

# %%
histogram_boxplot(train_data, 'delinq_2yrs')

# %% [markdown]
# This data looks like it follows a normal distribution but the heavy right-skew is due to those outliers once again. May need to clip.

# %%
histogram_boxplot(train_data, 'public_records')

# %%
#who are all of these rich people... lol
histogram_boxplot(train_data, 'revolving_balance')

# %%
#I need to double-check my data dictionary
#glad I checked because it's definitly not that!!!
# total acc is the total number of credit lines that the member has available. The x-axis now makes much more sense.
#looking at the outliers now I wonder if this dataset is including LLCs and other corporate entities because I'm not sure
#how a single individual gets 120 lines of credit. But as I said, I have much to learn.
histogram_boxplot(train_data, 'total_acc')

# %% [markdown]
# Nice to see a normal distribution after all those gnarly outliers! Here we can see a really good approximation to a Gaussian. However, There is still a good amount of data leakage to the right thanks to those outliers we see outside of our right whisker. I'll have to think about whether to treat these and if so, how to treat them when I start building the models. We're a long ways away from that though - still have data cleanup to do (missing value treatment) and more EDA to look for potential issues like multicollinearity in our data.

# %%
#ok total interest, makes more sense. I was like "how does someone end up with a 10,000 % interest rate"
histogram_boxplot(train_data, 'interest_receive')

# %%
histogram_boxplot(train_data, 'last_week_pay')

# %%
histogram_boxplot(train_data, 'total_current_balance')

# %%
histogram_boxplot(train_data, 'total_revolving_limit')

# %% [markdown]
# ### EDA - Categorial Data

# %%
train_data.columns
# Out:
# Index(['loan_amnt', 'loan_term', 'interest_rate', 'loan_grade',
#        'loan_subgrade', 'job_experience', 'home_ownership', 'annual_income',
#        'income_verification_status', 'loan_purpose', 'state_code',
#        'debt_to_income', 'delinq_2yrs', 'public_records', 'revolving_balance',
#        'total_acc', 'interest_receive', 'application_type', 'last_week_pay',
#        'total_current_balance', 'total_revolving_limit', 'default'],
#       dtype='object')

# %%
#I had an idea for something I wanted to try in Tableau which I'm currently learning to use.

# %%
labeled_barplot(train_data, 'loan_term', perc=True)

# %%
labeled_barplot(test_data, 'loan_term', perc=True)

# %% [markdown]
# 70% of the loan terms are for 3 years, 30% for 5 year terms, sampled well in both the training and test sets.

# %%
labeled_barplot(train_data, "loan_grade", perc=True)

# %%
labeled_barplot(test_data, "loan_grade", perc=True)

# %% [markdown]
# Yeah so grades will go from best to worst. A1 would be the top grade/subgrade, G5 would be the worst here. I'll likely due some feature engineering here since this represents ordinal data. Also, there is redundant information here as the subgrade includes information about the grade. We'll likely be able to drop the grade category entirely, the subgrade gives us more precise information. Let's take a look at those too.

# %%
labeled_barplot(train_data, 'loan_subgrade', perc=True)

# %%
labeled_barplot(test_data, 'loan_subgrade', perc=True)

# %% [markdown]
# Not only is this data ordinal, it also follows a normal (right-skewed) distribution! I think we'll definitely benefit from encoding this feature as numerical.

# %%
labeled_barplot(train_data, 'job_experience')

# %%
labeled_barplot(test_data, 'job_experience')

# %% [markdown]
# Ordinal here as well, and bi-modal. I'll think about whether I want to encode this information numerically.

# %%
labeled_barplot(train_data, 'home_ownership')

# %%
labeled_barplot(test_data, 'home_ownership')

# %%
labeled_barplot(train_data, 'income_verification_status', perc=True)

# %%
labeled_barplot(test_data, 'income_verification_status', perc=True)

# %%
labeled_barplot(train_data, 'loan_purpose', perc=True)

# %%
labeled_barplot(test_data, 'loan_purpose', perc=True)

# %%
labeled_barplot(train_data, 'state_code')

# %%
#I bet this more or less follows the population distribution of the US but you never know.
labeled_barplot(test_data, 'state_code')

# %%
labeled_barplot(train_data, 'application_type', perc=True)

# %%
labeled_barplot(test_data, 'application_type', perc=True)

# %% [markdown]
# Almost entirely individual loans represented in the data.

# %%
labeled_barplot(train_data, 'default', perc=True)

# %%
#next we need to do multi-variate analysis, missing data treatment, and think about our feature engineering. Our early visualization/EDA process is done, so I think this is a good time to push our work to github and take a break!

# %% [markdown]
# ## Part III. Feature Engineering and Encoding

# %% [markdown]
# ## Part IV. Building the Models on Training Data

# %% [markdown]
# ## Part V. Model Performance on Testing Data
